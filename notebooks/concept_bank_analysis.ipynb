# %% [markdown]
# # MIMIC-CXR SapBERT Concept Bank Analysis
#
# This notebook operates on an existing SapBERT concept bank (e.g. `generated/concept_bank_sapbert_mimic/`) and:
#
# - counts concepts vs frequency threshold for a chosen assertion label (default: `present`)
# - lists the top-K most frequent concepts with their CUIs and semantic types
#
# You can adapt the paths or assertion filter below to analyze other banks.

# %%
from pathlib import Path
import json
from collections import Counter

import pandas as pd

# Try to resolve the repo root so the notebook works whether it is
# launched from the repository root or from the analysis/ directory.
CWD = Path.cwd()
if (CWD / 'generated').exists():
    REPO_ROOT = CWD
elif (CWD.parent / 'generated').exists():
    REPO_ROOT = CWD.parent
else:
    REPO_ROOT = CWD

BANK_DIR = REPO_ROOT / 'generated' / 'concept_bank_sapbert_mimic'
STUDY_CONCEPTS_PATH = BANK_DIR / 'study_concepts.jsonl'
INVENTORY_PATH = BANK_DIR / 'concept_inventory.json'
SCHEMA_PATH = BANK_DIR / 'concept_schema.json'

ASSERTION = 'present'  # one of: 'present', 'absent', 'uncertain', 'any'
THRESHOLDS = [1, 3, 5, 10, 25, 50, 100]
TOP_K = 50

print(f'Repo root: {REPO_ROOT}')
print(f'Using study concepts from: {STUDY_CONCEPTS_PATH}')
if not STUDY_CONCEPTS_PATH.exists():
    raise FileNotFoundError(f'study_concepts.jsonl not found at {STUDY_CONCEPTS_PATH}')

inventory = {}
if SCHEMA_PATH.exists():
    with SCHEMA_PATH.open('r', encoding='utf-8') as handle:
        raw_schema = json.load(handle)
    if isinstance(raw_schema, dict):
        inventory = raw_schema
    print(f'Loaded curated schema with {len(inventory):,} entries from {SCHEMA_PATH}')
elif INVENTORY_PATH.exists():
    with INVENTORY_PATH.open('r', encoding='utf-8') as handle:
        raw_inventory = json.load(handle)
    if isinstance(raw_inventory, dict):
        inventory = raw_inventory
    print(f'Loaded inventory with {len(inventory):,} entries from {INVENTORY_PATH}')
else:
    print('No concept_inventory.json or concept_schema.json found; CUI and semantic_type columns will be empty.')
# Out:
# Repo root: /home/obadah/code/MedCLIP
# Using study concepts from: /home/obadah/code/MedCLIP/generated/concept_bank_sapbert_mimic/study_concepts.jsonl
# Loaded curated schema with 6,163 entries from /home/obadah/code/MedCLIP/generated/concept_bank_sapbert_mimic/concept_schema.json

# %%
counts = Counter()
total_studies = 0

with STUDY_CONCEPTS_PATH.open("r", encoding="utf-8") as handle:
    for line in handle:
        line = line.strip()
        if not line:
            continue
        record = json.loads(line)
        total_studies += 1
        for item in record.get("concepts", []):
            name = item.get("concept")
            if not name:
                continue
            if ASSERTION != "any" and item.get("assertion") != ASSERTION:
                continue
            counts[name] += 1

if not counts:
    raise RuntimeError(
        f"No concepts matched assertion={ASSERTION!r}. "
        "Try a different ASSERTION value or inspect the concept bank."
    )

print(f"Analyzed {total_studies:,} studies.")
print(f"Distinct concepts (assertion={ASSERTION!r}): {len(counts):,}")
# Out:
# Analyzed 7,071 studies.
# Distinct concepts (assertion='present'): 5,671

# %%
# Summary: number of concepts above each frequency threshold
summary_rows = []
for threshold in THRESHOLDS:
    kept = sum(1 for freq in counts.values() if freq >= threshold)
    summary_rows.append({"min_frequency": threshold, "num_concepts": kept})

summary_df = pd.DataFrame(summary_rows).sort_values("min_frequency").reset_index(drop=True)
summary_df
# Out:
#    min_frequency  num_concepts
# 0              1          5671
# 1              3          2521
# 2              5          1857
# 3             10          1239
# 4             25           733
# 5             50           458
# 6            100           275

# %%
# Top-K most frequent concepts with CUI and semantic type
rows = []
for rank, (name, freq) in enumerate(counts.most_common(TOP_K), start=1):
    meta = inventory.get(name, {}) if isinstance(inventory, dict) else {}
    label = meta.get("label") or name
    rows.append(
        {
            "rank": rank,
            "count": freq,
            "concept": label,
            "canonical_name": name,
            "cui": meta.get("cui"),
            "semantic_type": meta.get("semantic_type"),
        }
    )

top_df = pd.DataFrame(rows)
top_df
# Out:
#     rank  count                                    concept  \
# 0      1   3811                                       Lung
# 1      2   3372                                      Heart
# 2      3   2452                                    Pleural
# 3      4   2181                Patient condition unchanged
# 4      5   1917                                Mediastinum
# 5      6   1767                               Symptom mild
# 6      7   1611                                      Right
# 7      8   1542                             large effusion
# 8      9   1515                                        pul
# 9     10   1492                                       Size
# 10    11   1400                                      Hilar
# 11    12   1371                                Chest clear
# 12    13   1338                                       Left
# 13    14   1335                    Cardiovascular material
# 14    15   1300                                   Moderate
# 15    16   1193                    Normal cardiac function
# 16    17   1171                                       Lung
# 17    18   1144                         Abnormal smallness
# 18    19   1095                         Radiologic opacity
# 19    20   1061  Method of administration for tube feeding
# 20    21   1060                               Cardiomegaly
# 21    22    915                               Blood vessel
# 22    23    897                            increased along
# 23    24    889                     Cardiac surface groove
# 24    25    846                               stable small
# 25    26    841                                    Stomach
# 26    27    827           Structure of left pleural cavity
# 27    28    825          Structure of right pleural cavity
# 28    29    818                     Nogier auricular heart
# 29    30    809        Structure of pulmonary blood vessel
# 30    31    786                                 Right lung
# 31    32    780                                Atelectasis
# 32    33    778                                    Pleural
# 33    34    770                        Structure of carina
# 34    35    759                                  Bilateral
# 35    36    737                   Nasogastric tube in situ
# 36    37    735                                  Left lung
# 37    38    728                                      Chest
# 38    39    713                                   Improved
# 39    40    710                            Glomus jugulare
# 40    41    699                             Body positions
# 41    42    689                  Atrioventricular junction
# 42    43    675                      Consolidation of lung
# 43    44    660                        Rounded atelectasis
# 44    45    655                         Oedema - pulmonary
# 45    46    651                   Functional drainage tube
# 46    47    649                       Dilatation - cardiac
# 47    48    645                         Superior vena cava
# 48    49    640                                    Bicaval
# 49    50    621                       New medication added
#
#                                canonical_name       cui  semantic_type
# 0                                   Lung part  C1268107  BodyStructure
# 1                                  Heart, NOS  C0018787  BodyStructure
# 2                                     Pleural  C1522720  BodyStructure
# 3                 Patient condition unchanged  C0184763        Finding
# 4                            Mediastinum, NOS  C0025066  BodyStructure
# 5                                Symptom mild  C0436343        Finding
# 6                                       Right  C0205090  BodyStructure
# 7             Pleural effusion NOS (disorder)  C0032227        Finding
# 8                        PUL (body structure)  C0449197  BodyStructure
# 9                                Size finding  C1265584  BodyStructure
# 10                                      Hilar  C0205150  BodyStructure
# 11                                Chest clear  C0578395        Finding
# 12                                       Left  C0205091  BodyStructure
# 13                    Cardiovascular material  C0440759  BodyStructure
# 14                                   Moderate  C5201148        Finding
# 15                    Normal cardiac function  C5546750        Finding
# 16                            Lung field, NOS  C0225759  BodyStructure
# 17                         Abnormal smallness  C5922533        Finding
# 18                         Radiologic opacity  C1265598        Finding
# 19  Method of administration for tube feeding  C5567690        Finding
# 20                           Cardiomegaly NOS  C0018800        Finding
# 21                          Blood vessel, NOS  C0005847  BodyStructure
# 22       Increased level (laboratory finding)  C0586721        Finding
# 23                     Cardiac surface groove  C0457105  BodyStructure
# 24               Stabilized (qualifier value)  C0184512        Finding
# 25                          Stomach structure  C3714551  BodyStructure
# 26           Structure of left pleural cavity  C0225787  BodyStructure
# 27          Structure of right pleural cavity  C0225782  BodyStructure
# 28                     Nogier auricular heart  C0450935  BodyStructure
# 29        Structure of pulmonary blood vessel  C0459963  BodyStructure
# 30                            Right lung, NOS  C0225706  BodyStructure
# 31                           Atelectasis, NOS  C0004144        Finding
# 32                               Pleural part  C1268108  BodyStructure
# 33                        Structure of carina  C0225594  BodyStructure
# 34                                  Bilateral  C0238767  BodyStructure
# 35                   Nasogastric tube in situ  C3266113        Finding
# 36                             Left lung, NOS  C0225730  BodyStructure
# 37                                      Chest  C0817096  BodyStructure
# 38                                   Improved  C0184511        Finding
# 39                            Glomus jugulare  C0017670  BodyStructure
# 40                             Body positions  C1262869        Finding
# 41                  Atrioventricular junction  C0729580  BodyStructure
# 42                      Consolidation of lung  C0521530        Finding
# 43                        Rounded atelectasis  C2062952        Finding
# 44                     Oedema - pulmonary NOS  C0034063        Finding
# 45                   Functional drainage tube  C3266160        Finding
# 46                       Dilatation - cardiac  C0264732        Finding
# 47               Superior vena cava structure  C0042459  BodyStructure
# 48                                    Bicaval  C0444464  BodyStructure
# 49                       New medication added  C0555964        Finding
